# %% [markdown]
# # Gráficos dos agentes

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tradicional Maritime Search Single Agent

# %%
df_teadicional_1c = pd.read_csv("../results/traditional_search_1_agent_1c.csv")
df_teadicional_2c = pd.read_csv("../results/traditional_search_1_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_teadicional_1c["step"], df_teadicional_1c["accumulated_pos"])
plt.plot(df_teadicional_2c["step"], df_teadicional_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Tradicional Maritime Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_teadicional_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Tradicional Maritime Search 2 Agent

# %%
df_teadicional_1c = pd.read_csv("../results/traditional_search_2_agent_1c.csv")
df_teadicional_2c = pd.read_csv("../results/traditional_search_2_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_teadicional_1c["step"], df_teadicional_1c["accumulated_pos"])
plt.plot(df_teadicional_2c["step"], df_teadicional_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Tradicional Maritime Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_teadicional_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Tradicional Maritime Search 4 Agent

# %%
df_teadicional_1c = pd.read_csv("../results/traditional_search_4_agent_1c.csv")
df_teadicional_2c = pd.read_csv("../results/traditional_search_4_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_teadicional_1c["step"], df_teadicional_1c["accumulated_pos"])
plt.plot(df_teadicional_2c["step"], df_teadicional_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Tradicional Maritime Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_teadicional_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Expanding Square Search Single Agent

# %%
df_expanding_1c = pd.read_csv("../results/expanding_search_1_agent_1c.csv")
df_expanding_2c = pd.read_csv("../results/expanding_search_1_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_expanding_1c["step"], df_expanding_1c["accumulated_pos"])
plt.plot(df_expanding_2c["step"], df_expanding_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Expanding Square Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_expanding_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Expanding Square Search 2 Agent

# %%
df_expanding_1c = pd.read_csv("../results/expanding_search_2_agent_1c.csv")
df_expanding_2c = pd.read_csv("../results/expanding_search_2_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_expanding_1c["step"], df_expanding_1c["accumulated_pos"])
plt.plot(df_expanding_2c["step"], df_expanding_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Expanding Square Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_expanding_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Expanding Square Search 4 Agent

# %%
df_expanding_1c = pd.read_csv("../results/expanding_search_4_agent_1c.csv")
df_expanding_2c = pd.read_csv("../results/expanding_search_4_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_expanding_1c["step"], df_expanding_1c["accumulated_pos"])
plt.plot(df_expanding_2c["step"], df_expanding_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Expanding Square Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_expanding_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## AStar Search Single Agent

# %%
df_expanding_1c = pd.read_csv("../results/AStar_search_1_agent_1c.csv")
df_expanding_2c = pd.read_csv("../results/AStar_search_1_agent_2c.csv")

plt.figure(figsize=(8, 5))
plt.plot(df_expanding_1c["step"], df_expanding_1c["accumulated_pos"])
plt.plot(df_expanding_2c["step"], df_expanding_2c["accumulated_pos"])

plt.xlabel("Steps", fontsize=14, fontweight='bold')
plt.ylabel("Accumulated Position", fontsize=14, fontweight='bold')
plt.title("Expanding Square Search ", fontsize=16, fontweight='bold')

plt.xticks(ticks=range(0, df_expanding_1c["step"].max() + 1, 10))
plt.yticks(fontsize=12)

plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
